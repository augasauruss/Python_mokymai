# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Tavatevs\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]}) #column values in a list

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df=pd.DataFrame ([ [1, 2], [3, 4]], columns = ['coll1', 'coll2']) #row values in a list
df
# Out:
#    coll1  coll2
# 0      1      2
# 1      3      4

# %%
df = pd.DataFrame ( { "Age" : [20,30,40,25,55],"Name" : ['Bob', 'Carl', 'Tom', 'Vycka','John'] }, index= ['pirmas', 'antras','trecias', 'ketvirtas', 'penktas'])
df
# Out:
#            Age   Name
# pirmas      20    Bob
# antras      30   Carl
# trecias     40    Tom
# ketvirtas   25  Vycka
# penktas     55   John

# %%
df.index
# Out:
# Index(['pirmas', 'antras', 'trecias', 'ketvirtas', 'penktas'], dtype='object')

# %%
df.columns
# Out:
# Index(['Age', 'Name'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, pirmas to penktas
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     5 non-null      int64
#  1   Name    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 120.0+ bytes

# %%
series = df["Age"]
series
# Out:
# pirmas       20
# antras       30
# trecias      40
# ketvirtas    25
# penktas      55
# Name: Age, dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
wine_df = pd.read_csv('winemag-data.csv', index_col=0)

# %%
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Tavatevs\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
wine_df.to_excel('wine.xlsx')

# %%
wine_df.to_csv('wine_2.csv') #save to csv file when some changes are made to data

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_df.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
wine_df.tail()
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
#NaN - Not a Number , panasu i None, bet ne tas pats. 
#NaT - not a time.
pd.NA

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   34.000000
# std    13.874437
# min    20.000000
# 25%    25.000000
# 50%    30.000000
# 75%    40.000000
# max    55.000000

# %%
wine_df.describe(include='all')
# Out:
#        country                                        description designation  \
# count   129908                                             129971       92506
# unique      43                                             119955       37979
# top         US  Seductively tart in lemon pith, cranberry and ...     Reserve
# freq     54504                                                  3        2009
# mean       NaN                                                NaN         NaN
# std        NaN                                                NaN         NaN
# min        NaN                                                NaN         NaN
# 25%        NaN                                                NaN         NaN
# 50%        NaN                                                NaN         NaN
# 75%        NaN                                                NaN         NaN
# max        NaN                                                NaN         NaN
#
# ...

# %%
#duomenu filtravimas

# %%
wine_df['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_df[ ['country', 'province']]
# Out:
#          country           province
# 0          Italy  Sicily & Sardinia
# 1       Portugal              Douro
# 2             US             Oregon
# 3             US           Michigan
# 4             US             Oregon
# ...          ...                ...
# 129966   Germany              Mosel
# 129967        US             Oregon
# 129968    France             Alsace
# 129969    France             Alsace
# 129970    France             Alsace
#
# [129971 rows x 2 columns]

# %%
wine_df['country'][0]
# Out:
# 'Italy'

# %%
len(wine_df['description'][1].split())
# Out:
# 38

# %%
wine_df.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
sorted_df = wine_df.set_index('country').sort_index(level='country') #indeksas nuo salies ir salys isrikiuotos pagal sali (dabar abeleces tvarka)

# %%
sorted_df.iloc[0]
# Out:
# description              Odd aromas of bath soap and tropical fruits ar...
# designation                                     Valle Las Acequias Clase A
# points                                                                  81
# price                                                                  9.0
# province                                                  Mendoza Province
# region_1                                                           Mendoza
# region_2                                                               NaN
# taster_name                                              Michael Schachner
# taster_twitter_handle                                          @wineschach
# title                    Luis Segundo Correas 2015 Valle Las Acequias C...
# variety                                                         Chardonnay
# winery                                                Luis Segundo Correas
# Name: Argentina, dtype: object

# %%
sorted_df = wine_df.sort_index(level=0, ascending=False) #surikiavo nuo didziausio mazejimo tvarka
sorted_df.iloc[0]
# Out:
# country                                                             France
# description              Big, rich and off-dry, this is powered by inte...
# designation                                  Lieu-dit Harth Cuvée Caroline
# points                                                                  90
# price                                                                 21.0
# province                                                            Alsace
# region_1                                                            Alsace
# region_2                                                               NaN
# taster_name                                                     Roger Voss
# taster_twitter_handle                                           @vossroger
# title                    Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
# variety                                                     Gewürztraminer
# ...

# %%
#loc - gauna ta eilute, kurios indeksas yra [0], nesvarbu kur ji yra. Iloc duoda 1 eilute su [0].

# %%
sorted_df.loc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
sorted_df.loc[[0,135,10000]]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 135     Italy  The color is just beginning to show signs of b...
# 10000  France  This is a smooth, ripe, and rounded wine that'...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# 135                           Sorano      91   60.0           Piedmont
# 10000  Blanc de Noirs Grand Cru Brut      91    NaN          Champagne
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 135       Barolo      NaN            NaN                   NaN
# 10000  Champagne      NaN     Roger Voss            @vossroger
#
#                                                    title      variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
# ...

# %%
sorted_df.loc[[5,44],['points', 'price']]
# Out:
#     points  price
# 5       87   15.0
# 44      86    9.0

# %%
wine_df.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
tmp_df = wine_df.set_index( 'province'  )

# %%
tmp_df.head(2)
# Out:
#                     country  \
# province
# Sicily & Sardinia     Italy
# Douro              Portugal
#
#                                                          description  \
# province
# Sicily & Sardinia  Aromas include tropical fruit, broom, brimston...
# Douro              This is ripe and fruity, a wine that is smooth...
#
#                     designation  points  price region_1 region_2  \
# province
# Sicily & Sardinia  Vulkà Bianco      87    NaN     Etna      NaN
# Douro                  Avidagos      87   15.0      NaN      NaN
#
#                      taster_name taster_twitter_handle  \
# province
# Sicily & Sardinia  Kerin O’Keefe          @kerinokeefe
# Douro                 Roger Voss            @vossroger
#
#                                                            title  \
# province
# Sicily & Sardinia              Nicosia 2013 Vulkà Bianco  (Etna)
# Douro              Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
# ...

# %%
tmp_df = tmp_df.reset_index()
tmp_df.head(2)
# Out:
#             province   country  \
# 0  Sicily & Sardinia     Italy
# 1              Douro  Portugal
#
#                                          description   designation  points  \
# 0  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco      87
# 1  This is ripe and fruity, a wine that is smooth...      Avidagos      87
#
#    price region_1 region_2    taster_name taster_twitter_handle  \
# 0    NaN     Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 1   15.0      NaN      NaN     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
#duomenu filtravimas pagal reiksmes

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_df['taster_name'] == 'Roger Voss'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: taster_name, Length: 129971, dtype: bool

# %%
wine_df[wine_df['taster_name'] == 'Roger Voss']
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 7         France  This dry and restrained wine offers spice in p...
# 9         France  This has great depth of flavor with its fresh ...
# 11        France  This is a dry wine, very spicy, with a tight, ...
# 30        France  Red cherry fruit comes laced with light tannin...
# ...          ...                                                ...
# 129964    France  Initially quite muted, this wine slowly develo...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price    province  \
# 1                            Avidagos      87   15.0       Douro
# ...

# %%
wine_df[wine_df['country'] == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_df[(wine_df['country'] == 'Italy') & (wine_df['taster_name'] == 'Roger Voss') ]
# Out:
#        country                                        description  \
# 371      Italy  Fragrant, aromatic, grassy aromas give way to ...
# 372      Italy  A fresh, crisp style of Soave, brimming with g...
# 373      Italy  Crisp, green, grassy wine with fresh acidity a...
# 376      Italy  A well-judged, well-structured wine that balan...
# 384      Italy  Aromas of roses, pepper and spices make this a...
# ...        ...                                                ...
# 124826   Italy  Fresh, crisp, lightly grassy flavors make this...
# 125782   Italy  There is an amazing medley of aromas and flavo...
# 125791   Italy  This wine, which takes the family name of Fran...
# 127501   Italy  This is an elegant, smooth wine with fresh cle...
# 127505   Italy  A rich, complex style, with good concentration...
#
#                        designation  points  price            province  \
# 371                Castel Ringberg      88   23.0  Northeastern Italy
# ...

# %%
# & ~ and. & bitwise and
# | ~ or. | bitwise or
# ~ means NOT
# .isin()

# %%
wine_df[wine_df['country'].isin(['Italy', 'France']) & (wine_df['price']< 10)] ## rodys tik italijos ir prancuzijos duomenis
# Out:
#        country                                        description  \
# 42      France  This is a festive wine, with soft, ripe fruit ...
# 240     France  Dominated by Ugni Blanc, the grape also used i...
# 383      Italy  This lovely Chardonnay has just the right blen...
# 819     France  Soft, ripe and fruity, this is an immediately ...
# 1238    France  A wine that aims to bring out the casual side ...
# ...        ...                                                ...
# 127111  France  A crisp, very fresh wine with flavors of red c...
# 127116   Italy  Candied fruit, cherry liqueur and a touch of S...
# 127192   Italy  The nose is colored by some peach and white mi...
# 128866  France  Named after one of the Three Musketeers, this ...
# 129355   Italy  The quality-price ratio here is simply unbeata...
#
#                    designation  points  price            province  \
# 42                     Nouveau      86    9.0          Beaujolais
# ...

# %%
wine_df['points'].max()
# Out:
# 100

# %%
# susikurti nauju stulpeliu

# %%
wine_df['naujas_stulp']= 'naujas'
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_df['naujas_stulpelis']= wine_df['price'] * wine_df['points']/100
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
#metodai

# %%
wine_df['price'].mean()
# Out:
# 35.363389129985535

# %%
wine_df['points'].mean()
# Out:
# 88.44713820775404

# %%
wine_df['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
wine_df['taster_name'].value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
wine_df['description_len'] = wine_df['description'].map(len)
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
def word_count (txt):
    return len(txt.split())

# %%
wine_df['description_word'] = wine_df['description'].map(word_count)
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
def my_function (row):
    return str(row['country']) + " " + str(row['province'])

# %%
wine_df['place']= wine_df.apply(my_function,axis = 1)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
#drom Nans

# %%
wine_df_cleaned = wine_df.drop_duplicates()
wine_df_cleaned
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_df_cleaned[wine_df_cleaned['price'].isnull()].shape
# Out:
# (8395, 18)

# %%
wine_df_cleaned = wine_df_cleaned.dropna(how="any", subset= ['price']) # drop rows with NoN in price

# %%
# group by

# %%
grouped = wine_df_cleaned.groupby(['country', 'province'])[['points', 'price']].mean()

# %%
grouped.loc['Australia']
# Out:
#                       points      price
# province
# Australia Other    85.440000  12.466667
# New South Wales    87.719512  25.121951
# South Australia    89.039013  39.145701
# Tasmania           89.000000  36.527778
# Victoria           88.835017  43.070707
# Western Australia  88.934066  33.937729

# %%
wine_df_cleaned.to_csv("wine_cleaned.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv('wine_cleaned.csv', index_col=0)
df
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
df.rename( columns= {'tester_name': "Tester"}).head(2) ## pervadinti stulpelius
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...         NaN
#
#    points  price province           region_1           region_2   taster_name  \
# 1      87   15.0    Douro                NaN                NaN    Roger Voss
# 2      87   14.0   Oregon  Willamette Valley  Willamette Valley  Paul Gregutt
#
#   taster_twitter_handle                                          title  \
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine   Rainstorm 2013 Pinot Gris (Willamette Valley)
#
#           variety               winery naujas_stulp  naujas_stulpelis  \
# 1  Portuguese Red  Quinta dos Avidagos       naujas             13.05
# 2      Pinot Gris            Rainstorm       naujas             12.18
#
#    description_len  description_word           place
# ...

# %%
## dtypes
df['points'].dtype
# Out:
# dtype('int64')

# %%
df['region_2'].isna() ##- kiek eiluciu su nan
# Out:
# 1          True
# 2         False
# 3          True
# 4         False
# 5          True
#           ...
# 129966     True
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: region_2, Length: 111593, dtype: bool

# %%
df['region_2'].fillna('Not specified') ##- uzpildys nan su tekstu
# Out:
# 1             Not specified
# 2         Willamette Valley
# 3             Not specified
# 4         Willamette Valley
# 5             Not specified
#                 ...
# 129966        Not specified
# 129967         Oregon Other
# 129968        Not specified
# 129969        Not specified
# 129970        Not specified
# Name: region_2, Length: 111593, dtype: object

# %%
df.head(2)
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...         NaN
#
#    points  price province           region_1           region_2   taster_name  \
# 1      87   15.0    Douro                NaN                NaN    Roger Voss
# 2      87   14.0   Oregon  Willamette Valley  Willamette Valley  Paul Gregutt
#
#   taster_twitter_handle                                          title  \
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine   Rainstorm 2013 Pinot Gris (Willamette Valley)
#
#           variety               winery naujas_stulp  naujas_stulpelis  \
# 1  Portuguese Red  Quinta dos Avidagos       naujas             13.05
# 2      Pinot Gris            Rainstorm       naujas             12.18
#
#    description_len  description_word           place
# ...

# %%
df['taster_twitter_handle'].replace('@vossroger ', '@me') ##- pakeicia eilute kita
# Out:
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
# 5         @wineschach
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 111593, dtype: object

# %%
ca_videos = pd.read_csv ("CAvideos.csv")

# %%
ca_videos
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
gb_videos = pd.read_csv ("GBvideos.csv")
gb_videos
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
##join

# %%
ca_videos.join(gb_videos, lsuffix = "_left", rsuffix = '_right')
# Out:
#       video_id_left trending_date_left  \
# 0       n1WpP7iowLc           17.14.11
# 1       0dBIkQ4Mz1M           17.14.11
# 2       5qpjK5DgCt4           17.14.11
# 3       d380meD0W0M           17.14.11
# 4       2Vv-BfVoq4g           17.14.11
# ...             ...                ...
# 40876   sGolxsMSGfQ           18.14.06
# 40877   8HNuRNi8t70           18.14.06
# 40878   GWlKEM3m2EE           18.14.06
# 40879   lbMKLzQ4cNQ           18.14.06
# 40880   POTgw38-m58           18.14.06
#
#                                               title_left channel_title_left  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail          iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...       Rudy Mancuso
# 3                               I Dare You: GOING BALD!?           nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# ...

# %%
df_1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5'],
                   'B': ['B0', 'B1', 'B2', 'B3', 'B4', 'B5']})

# %%
ca_videos.head(2)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# ...

# %%
grouped = ca_videos.groupby(['channel_title','ratings_disabled' ]).sum()

# %%
grouped.loc[ ( slice(None) , True ), : ] ## [  (index_1 values, index_2 values), columns]
# Out:
#                                   category_id     views  likes  dislikes  \
# channel_title   ratings_disabled
# 5 News          True                       75    362795      0         0
# AresPromo       True                      840  12716522      0         0
# BBC Persian     True                       50     19028      0         0
# Bangtan Subs    True                       44    223448      0         0
# BeatFilms       True                       50   1377514      0         0
# ...                                       ...       ...    ...       ...
# 优酷              True                      672   1017576      0         0
# 新聞深喉嚨           True                      825   5149540      0         0
# 日清食品グループ公式チャンネル True                       72   2105781      0         0
# 沒脖子CLUB         True                       48     60172      0         0
# 뉴스지금            True                       50    523059      0         0
#
# ...

# %%
import numpy as np

# %%
x = np.linspace (0,10,20)
print (x)
# Out:
# [ 0.          0.52631579  1.05263158  1.57894737  2.10526316  2.63157895
#   3.15789474  3.68421053  4.21052632  4.73684211  5.26315789  5.78947368
#   6.31578947  6.84210526  7.36842105  7.89473684  8.42105263  8.94736842
#   9.47368421 10.        ]

# %%
y = x *2 
z = x ** 2

# %%
df = pd.DataFrame( [x,y,z], index=['x', 'multiply_by_2', 'squared']).T
df
# Out:
#             x  multiply_by_2     squared
# 0    0.000000       0.000000    0.000000
# 1    0.526316       1.052632    0.277008
# 2    1.052632       2.105263    1.108033
# 3    1.578947       3.157895    2.493075
# 4    2.105263       4.210526    4.432133
# 5    2.631579       5.263158    6.925208
# 6    3.157895       6.315789    9.972299
# 7    3.684211       7.368421   13.573407
# 8    4.210526       8.421053   17.728532
# 9    4.736842       9.473684   22.437673
# 10   5.263158      10.526316   27.700831
# 11   5.789474      11.578947   33.518006
# 12   6.315789      12.631579   39.889197
# 13   6.842105      13.684211   46.814404
# 14   7.368421      14.736842   54.293629
# 15   7.894737      15.789474   62.326870
# 16   8.421053      16.842105   70.914127
# 17   8.947368      17.894737   80.055402
# 18   9.473684      18.947368   89.750693
# 19  10.000000      20.000000  100.000000

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Tavatevs\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
df.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df.plot(title = "Grafikas")
# Out:
# <AxesSubplot:title={'center':'Grafikas'}>

# %%
ax = df.plot.scatter(x="x", y="multiply_by_2", color="DarkBlue", label="Group 1")
df.plot.scatter(x="x", y="x", color="r", label="Group 2", ax=ax)
df.plot.scatter(x="x", y="squared", color="DarkGreen", label="Group 2", ax=ax)
# Out:
# <AxesSubplot:xlabel='x', ylabel='squared'>

# %%
## matplotlib

# %%
import matplotlib.pyplot as plt
